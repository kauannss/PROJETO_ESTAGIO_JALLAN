# %%
import pandas as pd 

df = pd.read_csv("dados2.csv", sep=";")

print(df.dtypes)


df_novo = df[["Produto", "Valor", "NCM", "CSOSN"]]
# Out:
# Produto                  object
# Quantidade                int64
# Valor                    object
# NCM                      object
# CEST                     object
# CSOSN                     int64
# Observacao_Tributaria    object
# dtype: object
